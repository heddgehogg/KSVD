# %% [markdown]
# <a href="https://colab.research.google.com/github/heddgehogg/KSVD/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0_%D1%80%D0%BE%D0%B1%D0%BE%D1%82%D0%B0_4_%D0%A9%D0%B5%D1%80%D0%B1%D0%B8%D0%BD%D0%B0_%D0%BD%D0%B0_%D0%BF%D0%B0%D1%80%D1%96.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-90ed8886-573e-46f0-88af-e71d3b2e00b6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-90ed8886-573e-46f0-88af-e71d3b2e00b6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Museum_Visitors.csv')
df
# Out:
#                      Month  America Tropical Interpretive Center  Avila Adobe  \
# 0   01/01/2014 12:00:00 AM                                  6602        24778
# 1   02/01/2014 12:00:00 AM                                  5029        18976
# 2   03/01/2014 12:00:00 AM                                  8129        25231
# 3   04/01/2014 12:00:00 AM                                  2824        26989
# 4   05/01/2014 12:00:00 AM                                 10694        36883
# ..                     ...                                   ...          ...
# 80  09/01/2020 12:00:00 AM                                     0            0
# 81  10/01/2020 12:00:00 AM                                     0            0
# 82  11/01/2020 12:00:00 AM                                     0            0
# 83  12/01/2020 12:00:00 AM                                     0            0
# 84  01/01/2021 12:00:00 AM                                     0            0
#
# ...

# %% [markdown]
# 1. Пояснимо назви колонок

# %%
data = {
    "Стовпець": [
        "Month",
        "America Tropical Interpretive Center",
        "Avila Adobe",
        "Chinese American Museum",
        "Gateway to Nature Center",
        "Firehouse Museum",
        "Hellman Quon",
        "IAMLA",
        "Pico House",
        "Visitor Center/ El Tranquilo Gallery",
        "Museum of Social Justice",
        "Biscailuz Gallery/ PK Outdoor Exhibit"
    ],
    "Пояснення": [
        "Місяць, до якого належать наведені дані",
        "Центр, присвячений збереженню та інтерпретації фрески 'América Tropical'",
        "Найстаріший збережений будинок у Лос-Анджелесі, історична пам’ятка на Olvera Street",
        "Музей китайсько-американської культури й історії",
        "Центр, присвячений природі та екологічній освіті",
        "Музей у колишній пожежній станції, присвячений історії пожежної служби",
        "Історичний будинок у Чайнатауні, що показує життя китайсько-американської родини",
        "Italian American Museum of Los Angeles – музей італійської спадщини в Лос-Анджелесі",
        "Історичний готель, що використовується для подій та виставок",
        "Центр для відвідувачів з галереєю, можливо, виставки про культуру чи мистецтво",
        "Музей соціальної справедливості, з темами прав людини, імміграції тощо",
        "Галерея й експозиція просто неба, ймовірно з тимчасовими або культурними виставками"
    ]
}

df2 = pd.DataFrame(data)

df2
# Out:
#                                  Стовпець  \
# 0                                   Month
# 1    America Tropical Interpretive Center
# 2                             Avila Adobe
# 3                 Chinese American Museum
# 4                Gateway to Nature Center
# 5                        Firehouse Museum
# 6                            Hellman Quon
# 7                                   IAMLA
# 8                              Pico House
# 9    Visitor Center/ El Tranquilo Gallery
# 10               Museum of Social Justice
# 11  Biscailuz Gallery/ PK Outdoor Exhibit
#
#                                             Пояснення
# 0             Місяць, до якого належать наведені дані
# 1   Центр, присвячений збереженню та інтерпретації...
# 2   Найстаріший збережений будинок у Лос-Анджелесі...
# 3    Музей китайсько-американської культури й історії
# 4    Центр, присвячений природі та екологічній освіті
# 5   Музей у колишній пожежній станції, присвячений...
# ...

# %% [markdown]
# 2. Перевіримо чи є пропуски у датасеті.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 12 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Month                                  85 non-null     object
#  1   America Tropical Interpretive Center   85 non-null     int64
#  2   Avila Adobe                            85 non-null     int64
#  3   Chinese American Museum                85 non-null     int64
#  4   Gateway to Nature Center               32 non-null     float64
#  5   Firehouse Museum                       85 non-null     int64
#  6   Hellman Quon                           26 non-null     float64
#  7   IAMLA                                  54 non-null     float64
#  8   Pico House                             83 non-null     float64
#  9   Visitor Center/ El Tranquilo Gallery   45 non-null     float64
# ...

# %%
df.isnull().sum()
# Out:
# Month                                     0
# America Tropical Interpretive Center      0
# Avila Adobe                               0
# Chinese American Museum                   0
# Gateway to Nature Center                 53
# Firehouse Museum                          0
# Hellman Quon                             59
# IAMLA                                    31
# Pico House                                2
# Visitor Center/ El Tranquilo Gallery     40
# Museum of Social Justice                 48
# Biscailuz Gallery/ PK Outdoor Exhibit    46
# dtype: int64

# %% [markdown]
# 3. Перевіримо кількість дублікатів

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 4. За допомогою середніх значень заповнимо пропуски.

# %%
df = df.fillna(df.mean(numeric_only=True), axis=0)

# %%
df.isnull().sum()
# Out:
# Month                                    0
# America Tropical Interpretive Center     0
# Avila Adobe                              0
# Chinese American Museum                  0
# Gateway to Nature Center                 0
# Firehouse Museum                         0
# Hellman Quon                             0
# IAMLA                                    0
# Pico House                               0
# Visitor Center/ El Tranquilo Gallery     0
# Museum of Social Justice                 0
# Biscailuz Gallery/ PK Outdoor Exhibit    0
# dtype: int64

# %% [markdown]
# 5. Виведемо перші 5 рядків.

# %%
df.head()
# Out:
#                     Month  America Tropical Interpretive Center  Avila Adobe  \
# 0  01/01/2014 12:00:00 AM                                  6602        24778
# 1  02/01/2014 12:00:00 AM                                  5029        18976
# 2  03/01/2014 12:00:00 AM                                  8129        25231
# 3  04/01/2014 12:00:00 AM                                  2824        26989
# 4  05/01/2014 12:00:00 AM                                 10694        36883
#
#    Chinese American Museum  Gateway to Nature Center  Firehouse Museum  \
# 0                     1581                  1247.375              4486
# 1                     1785                  1247.375              4172
# 2                     3229                  1247.375              7082
# 3                     2129                  1247.375              6756
# 4                     3676                  1247.375             10858
#
#    Hellman Quon       IAMLA  Pico House   \
# ...

# %% [markdown]
# 6. Перевіримо основну інформаці. по датасету.

# %%
df.describe()
# Out:
#        America Tropical Interpretive Center   Avila Adobe  \
# count                             85.000000     85.000000
# mean                            5637.694118  19904.952941
# std                             3277.453044   9495.340548
# min                                0.000000      0.000000
# 25%                             3891.000000  17056.000000
# 50%                             5705.000000  20815.000000
# 75%                             6955.000000  25234.000000
# max                            13490.000000  41242.000000
#
#        Chinese American Museum  Gateway to Nature Center  Firehouse Museum  \
# count                85.000000                 85.000000         85.000000
# mean               2359.117647               1247.375000       5286.776471
# std                1360.427221                736.364942       6591.535926
# min                   0.000000                  0.000000          0.000000
# ...

# %% [markdown]
# 7. Замінимо назви колонок на назви з маленької букви та замінимо пробіл на нижнє підкреслення.

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('/', '_').str.replace('__', '_').str.strip()
df
# Out:
#                      month  america_tropical_interpretive_center  avila_adobe  \
# 0   01/01/2014 12:00:00 AM                                  6602        24778
# 1   02/01/2014 12:00:00 AM                                  5029        18976
# 2   03/01/2014 12:00:00 AM                                  8129        25231
# 3   04/01/2014 12:00:00 AM                                  2824        26989
# 4   05/01/2014 12:00:00 AM                                 10694        36883
# ..                     ...                                   ...          ...
# 80  09/01/2020 12:00:00 AM                                     0            0
# 81  10/01/2020 12:00:00 AM                                     0            0
# 82  11/01/2020 12:00:00 AM                                     0            0
# 83  12/01/2020 12:00:00 AM                                     0            0
# 84  01/01/2021 12:00:00 AM                                     0            0
#
# ...

# %% [markdown]
# 8. Знайдемо мінімальну та максимальну кількість відвідувачів для кожного музею за 2018 рік.

# %%
df['month'] = pd.to_datetime(df['month'], format='%m/%d/%Y %I:%M:%S %p')

df_2018 = df[df['month'].dt.year == 2018]

min_visitors = df_2018.iloc[:, 1:].min()
max_visitors = df_2018.iloc[:, 1:].max()
result = pd.DataFrame({'min': min_visitors, 'max': max_visitors})

result
# Out:
#                                                min           max
# america_tropical_interpretive_center   3180.000000   5837.000000
# avila_adobe                           14718.000000  25173.000000
# chinese_american_museum                2078.000000   4960.000000
# gateway_to_nature_center               1247.375000   1247.375000
# firehouse_museum                       3306.000000   8013.000000
# hellman_quon                            353.461538    353.461538
# iamla                                   965.000000   1601.000000
# pico_house_                             185.000000   2140.000000
# visitor_center_el_tranquilo_gallery    2634.800000   2634.800000
# museum_of_social_justice               2332.000000   3686.000000
# biscailuz_gallery_pk_outdoor_exhibit    349.000000   1790.000000

# %% [markdown]
# 9. Обчислимо середню кількість відвідувачів для кожного музею протягом всього періоду.

# %%
avg_visitors = df.iloc[:, 1:].mean()
avg_visitors
# Out:
# america_tropical_interpretive_center     5637.694118
# avila_adobe                             19904.952941
# chinese_american_museum                  2359.117647
# gateway_to_nature_center                 1247.375000
# firehouse_museum                         5286.776471
# hellman_quon                              353.461538
# iamla                                     882.611111
# pico_house_                              1329.710843
# visitor_center_el_tranquilo_gallery      2634.800000
# museum_of_social_justice                 2125.972973
# biscailuz_gallery_pk_outdoor_exhibit     1088.615385
# dtype: float64

# %% [markdown]
# 10. Визначимо місяці з найвищою і найнижчою загальною кількістю відвідувачів серед усіх музеїв для 2015 року. Виведемо назви місяців.

# %%
df_2015 = df[df['month'].dt.year == 2015].copy()

df_2015['total_visitors'] = df_2015.iloc[:, 1:].sum(axis=1)

min_row = df_2015.loc[df_2015['total_visitors'].idxmin()]
max_row = df_2015.loc[df_2015['total_visitors'].idxmax()]

min_month = min_row['month'].strftime('%B')
max_month = max_row['month'].strftime('%B')
print('Місяць з найнижчою загальною кількістю відвідувачів -', min_month)
print('Місяць з найвищою загальною кількістю відвідувачів -', max_month)
# Out:
# Місяць з найнижчою загальною кількістю відвідувачів - February
# Місяць з найвищою загальною кількістю відвідувачів - May

# %% [markdown]
# 11. Порівняємо кількість відвідувачів музею "Avila Adobe" у літні і зимові місяці 2018 року.

# %%
df_2018 = df[df['month'].dt.year == 2018].copy()

df_2018['month_num'] = df_2018['month'].dt.month

summer = df_2018[df_2018['month_num'].isin([6, 7, 8])]['avila_adobe'].sum()
winter = df_2018[df_2018['month_num'].isin([1, 2, 12])]['avila_adobe'].sum()

print(f"Влітку музей 'Avila Adobe' відвідали: {summer} людей")
print(f"Взимку музей 'Avila Adobe' відвідали: {winter} людей")
# Out:
# Влітку музей 'Avila Adobe' відвідали: 66122 людей
# Взимку музей 'Avila Adobe' відвідали: 48705 людей

# %% [markdown]
# 12. Знайдемо кореляцію між кількістю відвідувачів в кожному з музеїв та датами у 2016 році.

# %%
df.corr()
# Out:
#                                          month  \
# month                                 1.000000
# america_tropical_interpretive_center -0.781557
# avila_adobe                          -0.738084
# chinese_american_museum              -0.315742
# gateway_to_nature_center             -0.331943
# firehouse_museum                     -0.371774
# hellman_quon                          0.020910
# iamla                                -0.216164
# pico_house_                          -0.475915
# visitor_center_el_tranquilo_gallery  -0.013956
# museum_of_social_justice             -0.150472
# biscailuz_gallery_pk_outdoor_exhibit  0.074758
#
#                                       america_tropical_interpretive_center  \
# month                                                            -0.781557
# america_tropical_interpretive_center                              1.000000
# avila_adobe                                                       0.854877
# ...

# %% [markdown]
# 13. Побудуємо лінійний графік (відвідуваність Avila Adobe з часом)

# %%
sns.set_theme(style='darkgrid')
sns.lineplot(data=df, x='month', y='avila_adobe')
plt.title('Avila Adobe: Відвідуваність з часом')
plt.show()

# %% [markdown]
# 14. Побудуємо boxplot (розподіл відвідувачів Chinese American Museum по роках).

# %%
df['month'] = pd.to_datetime(df['month'])
df['year'] = df['month'].dt.year

sns.set_theme(style='darkgrid')
plt.figure(figsize=(10, 6))
sns.boxplot(x='year', y='chinese_american_museum', hue='year', data=df, palette='pastel', legend=False)
plt.title('Розподіл відвідувачів Chinese American Museum по роках')
plt.xlabel('Рік')
plt.ylabel('Кількість відвідувачів')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 15. Побудуємо heatmap (кореляція між музеями).

# %%
museum_cols = df.select_dtypes(include='number').drop(columns=['year'], errors='ignore')

corr = museum_cols.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Кореляція між музеями')
plt.tight_layout()
plt.show()

# %% [markdown]
# 16. Побудуємо histogram (розподіл кількості відвідувачів Gateway to Nature Center).

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x='gateway_to_nature_center', bins=20, kde=False, color='skyblue')
plt.title('Розподіл кількості відвідувачів Gateway to Nature Center')
plt.xlabel('Кількість відвідувачів')
plt.ylabel('Кількість місяців')
plt.tight_layout()
plt.show()

# %% [markdown]
# 17. Побудуємо barplot (середня кількість відвідувачів по музеях за всі роки).

# %%
mean_visitors = df.drop(columns='month').mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=mean_visitors.values, y=mean_visitors.index, palette='coolwarm')
plt.title('Середня кількість відвідувачів по музеях (усі роки)')
plt.xlabel('Середня кількість відвідувачів')
plt.ylabel('Музей')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-36-707e7c15628a>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=mean_visitors.values, y=mean_visitors.index, palette='coolwarm')
